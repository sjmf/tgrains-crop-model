# %%
from ctypes import *

# %%
mylib = cdll.LoadLibrary("./liblandscape_model.so")

# %%
# !!nm -D ./liblandscape_model.so
# Out:
# ['0000000000201008 A __bss_start',
#  '                 w __cxa_finalize',
#  '0000000000201008 A _edata',
#  '0000000000201018 A _end',
#  '0000000000000648 T _fini',
#  '                 w __gmon_start__',
#  '                 U __gxx_personality_v0',
#  '00000000000004f8 T _init',
#  '                 w _Jv_RegisterClasses',
#  '0000000000000600 T _Z3addii']

# %%
mylib._Z3addii(3,6)
# Out:
# 9
