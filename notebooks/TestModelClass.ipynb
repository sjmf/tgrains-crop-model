# %%
# %cd /vagrant_data/server/model
# Out:
# /vagrant_data/server/model

# %%
from CropModel import CropModel

# %%
model = CropModel()

# %%
model.landscape = 102

# %%
model.initialise_model()

# %%
model.run_model()

# %%
print(model)
# Out:
# myUniqueLandscapeID:
# 	102
# maxCropArea:
# 	60000.0
# cropAreas:
# 	[300.0, 400.0, 100.0, 600.0, 500.0, 400.0, 200.0, 200.0, 800.0, 800.0]
# livestockNumbers:
# 	[1000, 2000, 3000]
# greenhouseGasEmissions:
# 	0.3097674418604651
# nLeach:
# 	0.47186046511627905
# profit:
# 	129.41860465116278
# production:
# 	37.30232558139535
# pesticideImpacts:
# 	[0.23593023255813952, 1.1796511627906976, 0.7077906976744186, 0.3538953488372093, 0.42467441860465116]
# nutritionaldelivery:
# 	[21.428571428571427, 19.047619047619047, 9.523809523809524, 0.19047619047619047, 3.8095238095238093, 11.428571428571429, 17.142857142857142, 0.2857142857142857, 11.428571428571429, 5.714285714285714]
# healthRiskFactors:
# 	[1.1142857142857143, 1.1142857142857143, 1.126984126984127, 1.126984126984127]
# errorFlag:
# 	0

# %%
model.get_crop_string(0)
# Out:
# 'Wheat'

# %%
model.get_landscape_string(model.landscape)
# Out:
# 'South Wales'

# %%
list(model.cropAreasBAU)
# Out:
# [300.0, 400.0, 100.0, 600.0, 500.0, 400.0, 200.0, 200.0, 800.0, 800.0]

# %%
[model.get_crop_string(i) for i in range(len(list(model.cropAreasBAU)))]
# Out:
# ['Wheat',
#  'Barley',
#  'Oats',
#  'Oilseed Rape',
#  'Vegetables',
#  'Livestock Grazing',
#  'Maize',
#  'Beans',
#  'Potatoes',
#  'Onion']

# %%
[model.get_livestock_string(i) for i in range(len(list(model.livestockNumbersBAU)))]
# Out:
# ['Cow', 'Sheep', 'Chicken']

# %%
list(model.livestockNumbersBAU)
# Out:
# [1000, 2000, 3000]

# %%
model.cropData.livestockNumbers
# Out:
# <cppyy.gbl.std.vector<int> object at 0x5650e47ec2d8>
